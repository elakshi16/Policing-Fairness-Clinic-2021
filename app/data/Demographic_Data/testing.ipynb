# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install fiona
# !pip install shapely

import fiona
from shapely.geometry import shape, mapping, Point, Polygon, MultiPolygon
from shapely.ops import unary_union

import pandas as pd
import numpy as np
import matplotlib
import math as math
import pickle
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...

# %%
DATA_PATH = "/content/drive/Shareddrives/Policing Fairness Clinic/Data/"


def open_tracts():
  tract_layer = fiona.open(DATA_PATH + "Demographic_Data/tl_2021_06_tract/tl_2021_06_tract.shp")
  # print(layer)
  # print(type(layer))
  # print(f"num tracts? {len(layer)}")
  # print(layer[0])
  # print(type(layer[0]))
  # tract_list = [shape(geom['geometry']) for geom in layer]
  # # print(tract_list)
  # print(tract_list[1])
  # print(tract_list[1].bounds)

  LA_layers = fiona.open(DATA_PATH + "LAPD_Divisions/LAPD_Divisions.shp")
  precincts = [shape(geom['geometry']) for geom in LA_layers]
  LA_union = unary_union(precincts)

  la_tracts = []
  for datum in tract_layer:
    # print(datum)
    tract_poly = shape(datum['geometry'])
    if tract_poly.within(LA_union):
      print(datum)
      prop_dict = datum['properties']

# %%
open_tracts()

# %% [markdown]
# HERE WE WILL CREATE A MAPPING BETWEEN CENSUS TRACT NAME AND POPULATION

# %%
def get_tract_pop(tract_name):
  '''
  returns population of tract as integer
  '''

# %% [markdown]
# HERE WE FIND WHICH TRACTS ARE IN LA CITY
